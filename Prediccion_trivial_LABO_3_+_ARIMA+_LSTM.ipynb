# %% [markdown]
# <a href="https://colab.research.google.com/github/VeronicaGarciaRio/labo3-2024v/blob/main/Prediccion_trivial_LABO_3_%2B_ARIMA%2B_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## UNO LOS DOS TXT

# %%
import pandas as pd
import numpy as np

# %%
file_path = '/content/sell-in.txt'
df = pd.read_csv(file_path, sep='\t')

# %%
file_path2=  '/content/tb_productos.txt'
df2 = pd.read_csv(file_path2, sep='\t')

# %%
# Realizar una unión en los DataFrames basada en el campo común 'codigo_id_producto'
df_unif = pd.merge(df, df2, on='product_id', how='inner')

# Guardar el resultado en un nuevo archivo de texto si es necesario
#df_unif.to_csv('df_unif.txt', index=False)

# %%
df_filtered = df_unif[df_unif['customer_id'] == 10234]
print(df_filtered)
# Out:
#          periodo  customer_id  product_id  plan_precios_cuidados  \
# 0         201701        10234       20524                      0
# 185       201703        10234       20524                      0
# 310       201706        10234       20524                      0
# 731       201711        10234       20524                      0
# 1593      201812        10234       20524                      0
# ...          ...          ...         ...                    ...
# 2761730   201909        10234       20815                      0
# 2761910   201909        10234       20213                      0
# 2762150   201909        10234       20257                      0
# 2762663   201909        10234       20694                      0
# 2763111   201909        10234       21129                      0
#
#          cust_request_qty  cust_request_tn       tn cat1     cat2  \
# 0                       2          0.05300  0.05300   HC  VAJILLA
# ...

# %%
df_unif
# Out:
#          periodo  customer_id  product_id  plan_precios_cuidados  \
# 0         201701        10234       20524                      0
# 1         201701        10032       20524                      0
# 2         201701        10217       20524                      0
# 3         201701        10125       20524                      0
# 4         201701        10012       20524                      0
# ...          ...          ...         ...                    ...
# 2763757   201909        10056       20703                      0
# 2763758   201909        10320       20703                      0
# 2763759   201909        10374       20703                      0
# 2763760   201909        10447       20703                      0
# 2763761   201909        10249       20703                      0
#
#          cust_request_qty  cust_request_tn       tn cat1     cat2  \
# 0                       2          0.05300  0.05300   HC  VAJILLA
# ...

# %%
print(df_unif['periodo'].unique())
# Out:
# [201701 201702 201703 201704 201705 201706 201707 201708 201709 201710
#  201711 201712 201801 201802 201803 201804 201805 201806 201807 201808
#  201809 201810 201811 201812 201901 201902 201903 201904 201905 201906
#  201907 201908 201909]

# %% [markdown]
# ##Caso 1

# %%
df_marzo=df_unif[df_unif['periodo'] == 201903]

# %%
df_marzo
# Out:
# Empty DataFrame
# Columns: [periodo, customer_id, product_id, plan_precios_cuidados, cust_request_qty, cust_request_tn, tn, cat1, cat2, cat3, brand, sku_size]
# Index: []

# %%
df_mayo= df_unif[df_unif['periodo'] == 201905]

# %%
df_mayo
# Out:
# Empty DataFrame
# Columns: [periodo, customer_id, product_id, plan_precios_cuidados, cust_request_qty, cust_request_tn, tn, cat1, cat2, cat3, brand, sku_size]
# Index: []

# %%
df_marzo2 = df_marzo.groupby('product_id')['tn'].sum().reset_index()

# %%
df_mayo2 = df_mayo.groupby('product_id')['tn'].sum().reset_index()

# %%
df_mm = pd.merge(df_marzo2, df_mayo2, on=['product_id'], how='left')
df_mm.head(10)
# Out:
# Empty DataFrame
# Columns: [tn_x, product_id, tn_y]
# Index: []

# %%
df_mm['AbsoluteError'] = abs(df_mm['tn_x'] - df_mm['tn_y'])

# %%
df_mm.head(10)
# Out:
# Empty DataFrame
# Columns: [tn_x, product_id, tn_y, AbsoluteError]
# Index: []

# %%
total_forecast_error = df_mm['AbsoluteError'].sum() / df_mm['tn_x'].sum()
print(total_forecast_error)
# Out:
# nan
# <ipython-input-16-0c9a41d1e74c>:1: RuntimeWarning: invalid value encountered in scalar divide
#   total_forecast_error = df_mm['AbsoluteError'].sum() / df_mm['tn_x'].sum()

# %% [markdown]
# ##Caso 2

# %%
# Filtra el DataFrame para los períodos de interés (en este caso, de nov a abr de 2019)
periodos_interes = [201811, 201812, 201901, 201902, 201903, 201904]
df_seis_meses = df_unif[df_unif['periodo'].isin(periodos_interes)]

# %%
df_seis_meses[df_seis_meses['product_id'] == 20001]
# Out:
# Empty DataFrame
# Columns: [periodo, customer_id, product_id, plan_precios_cuidados, cust_request_qty, cust_request_tn, tn, cat1, cat2, cat3, brand, sku_size]
# Index: []

# %%
df_seis_meses2 = df_seis_meses.groupby('product_id')['tn'].agg(['sum']).reset_index()

# %%
df_seis_meses2['promedio_tn'] = df_seis_meses2['sum'] / 6

# Renombrar la columna 'sum' a 'total_tn' para mayor claridad
df_seis_meses2.rename(columns={'sum': 'total_tn'}, inplace=True)

# %%
df_seis_meses2
# Out:
# Empty DataFrame
# Columns: [product_id, total_tn, promedio_tn]
# Index: []

# %%
df_mm2 = pd.merge(df_marzo2, df_seis_meses2, on=['product_id'], how='left')
df_mm2.head(10)
# Out:
# Empty DataFrame
# Columns: [tn, product_id, total_tn, promedio_tn]
# Index: []

# %%
df_mm2['AbsoluteError'] = abs(df_mm2['tn'] - df_mm2['promedio_tn'])

# %%
df_mm2
# Out:
# Empty DataFrame
# Columns: [tn, product_id, total_tn, promedio_tn, AbsoluteError]
# Index: []

# %%
total_forecast_error2 = df_mm2['AbsoluteError'].sum() / df_mm2['tn'].sum()
print(total_forecast_error2)
# Out:
# nan
# <ipython-input-25-429b0ee82482>:1: RuntimeWarning: invalid value encountered in scalar divide
#   total_forecast_error2 = df_mm2['AbsoluteError'].sum() / df_mm2['tn'].sum()

# %% [markdown]
# KAGGLE

# %%
file_path3= '/content/productos_a_predecir.txt'
df3 = pd.read_csv(file_path3, sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-a118de02a301> in <cell line: 2>()
#       1 file_path3= '/content/productos_a_predecir.txt'
# ----> 2 df3 = pd.read_csv(file_path3, sep='\t')
#
# ...

# %%
# Realizar una unión en los DataFrames basada en el campo común 'codigo_id_producto'
df_unif2 = pd.merge(df, df3, on='product_id', how='inner')

# Guardar el resultado en un nuevo archivo de texto si es necesario
#df_unif.to_csv('df_unif.txt', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c53680f9ea20> in <cell line: 2>()
#       1 # Realizar una unión en los DataFrames basada en el campo común 'codigo_id_producto'
# ----> 2 df_unif2 = pd.merge(df, df3, on='product_id', how='inner')
#       3
#       4 # Guardar el resultado en un nuevo archivo de texto si es necesario
#       5 #df_unif.to_csv('df_unif.txt', index=False)
#
# NameError: name 'df3' is not defined

# %%
#df_feb= df_unif2[df_unif2['periodo'] == 202002]

# %%
# Filtra el DataFrame para los períodos de interés (en este caso, de nov a abr de 2019)
periodos_interes2 = [201811, 201812, 201901, 201902, 201903, 201904, 201905, 201906, 201907, 201908, 201909, 201910, 201911, 201912]
df_12_meses = df_unif2[df_unif2['periodo'].isin(periodos_interes2)]

# %%
df_12_meses2 = df_12_meses.groupby('product_id')['tn'].agg(['sum']).reset_index()

# %%
df_12_meses2

# %%
df_12_meses2['sum'] = df_12_meses2['sum'] / 12

# Renombrar la columna 'sum' a 'total_tn' para mayor claridad
df_12_meses2.rename(columns={'sum': 'total_tn'}, inplace=True)

# %%
df_12_meses2

# %% [markdown]
# ver si hay que renombrar la columna

# %%
# Guardar el resultado en un nuevo archivo de texto si es necesario
df_12_meses2.to_csv('df_12_meses2.csv', index=False)

# %% [markdown]
# otra opcion para kaggle

# %%
# Filtra el DataFrame para los períodos de interés (en este caso, de nov a abr de 2019)
periodos_interes = [201811, 201812, 201901, 201902, 201903, 201904, 201905, 201906, 201907, 201908, 201909, 201910, 201911, 201912]
df_12_meses = df_unif2[df_unif2['periodo'].isin(periodos_interes2)]

# %%
df_12_meses2 = df_12_meses.groupby('product_id')['tn'].agg(['sum']).reset_index()

# %%
df_12_meses2['sum'] = df_12_meses2['sum'] / 14

# Renombrar la columna 'sum' a 'total_tn' para mayor claridad
df_12_meses2.rename(columns={'sum': 'total_tn'}, inplace=True)

# %%
# Guardar el resultado en un nuevo archivo de texto si es necesario
df_12_meses2.to_csv('df_12_meses14.csv', index=False)

# %% [markdown]
# # KAGGLE ARIMA

# %%
# monta G-drive en entorno COLAB
from google.colab import drive
drive.mount('/content/drive/')

file_path3= '/content/drive/MyDrive/productos_a_predecir.txt'
productos_predecir = pd.read_csv(file_path3, sep='\t')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/sell-in.txt'
sell_in = pd.read_csv(file_path, sep='\t')

# %%
# Definir los periodos de interés
#periodos = [201701,201702,201703,201704,201705,201706,201707,201708,201709,201710,201711,201712,201801,201802,201803,201804,201805,201806,201807,201808,201809,201810,201811,201812,201901,201902,201903,201904,201905,201906,201907,201908,201909,201910,201911,201912]
periodos = [201901,201902,201903,201904,201905,201906,201907,201908,201909,201910,201911,201912]
# Filtrar las filas correspondientes a los periodos de interés
sell_in_completo = sell_in[sell_in['periodo'].isin(periodos)]

# %%
sell_in_completo.head()
# Out:
#          periodo  customer_id  product_id  plan_precios_cuidados  \
# 2035338   201901        10461       20524                      0
# 2035339   201901        10035       20524                      0
# 2035340   201901        10027       20524                      0
# 2035341   201901        10159       20524                      0
# 2035342   201901        10282       20524                      0
#
#          cust_request_qty  cust_request_tn       tn
# 2035338                 1          0.01514  0.01514
# 2035339                 1          0.03786  0.03786
# 2035340                 6          0.14385  0.14385
# 2035341                 3          0.02271  0.02271
# 2035342                 1          0.01514  0.01514

# %%
dataset = pd.merge(productos_predecir, sell_in_completo, on='product_id', how='inner')

# %%
sell_in_completo = dataset.groupby(['periodo', 'product_id'])['tn'].sum().reset_index()

# %%
sell_in_completo.head()
# Out:
#    periodo  product_id          tn
# 0   201901       20001  1275.77351
# 1   201901       20002  1266.78751
# 2   201901       20003   964.76919
# 3   201901       20004   511.33713
# 4   201901       20005   363.58438

# %%
sell_in_completo.to_csv('/content/drive/MyDrive/sell_in_completo.csv', index=False)

# %%
sell_in_completo['periodo'] = pd.to_datetime(sell_in_completo['periodo'].astype(str) + '01', format='%Y%m%d')

# %%
sell_in_completo.set_index("periodo", inplace=True)

# %%
# %pip install pmdarima
from statsmodels.tsa.arima.model import ARIMA
from pmdarima.arima import auto_arima

# %%
productos_unicos = sell_in_completo['product_id'].unique().tolist()
print(productos_unicos)
len(productos_unicos)
# Out:
# [20001, 20002, 20003, 20004, 20005, 20006, 20007, 20008, 20009, 20010, 20011, 20012, 20013, 20014, 20015, 20016, 20017, 20018, 20019, 20020, 20021, 20022, 20023, 20024, 20025, 20026, 20027, 20028, 20029, 20030, 20031, 20033, 20035, 20037, 20038, 20039, 20041, 20042, 20043, 20044, 20045, 20046, 20047, 20049, 20050, 20051, 20052, 20053, 20054, 20055, 20056, 20057, 20058, 20059, 20061, 20062, 20063, 20065, 20066, 20067, 20068, 20069, 20070, 20071, 20072, 20073, 20074, 20075, 20076, 20077, 20079, 20080, 20081, 20082, 20084, 20085, 20086, 20087, 20089, 20090, 20091, 20092, 20093, 20094, 20095, 20096, 20097, 20099, 20100, 20101, 20102, 20103, 20106, 20107, 20108, 20109, 20111, 20112, 20114, 20116, 20117, 20118, 20119, 20120, 20121, 20122, 20123, 20124, 20125, 20126, 20129, 20130, 20132, 20133, 20134, 20135, 20137, 20138, 20139, 20140, 20142, 20143, 20144, 20145, 20146, 20148, 20150, 20151, 20152, 20153, 20155, 20157, 20158, 20159, 20160, 20161, 20162, 20164, 20166, 20167, 20168, 20170, 201
# ...

# %%
# Lista para acumular las filas de resultados
resultados_por_producto = []

for producto in productos_unicos:
    # Filtrar datos para el producto específico
    aux = sell_in_completo[sell_in_completo["product_id"] == producto].drop(columns=["product_id"])

    try:
        # Determinar el mejor modelo ARIMA automáticamente
        modelo_auto = auto_arima(aux['tn'], seasonal=True, suppress_warnings=True)

        # Ajustar el modelo ARIMA automáticamente
        modelo = ARIMA(aux['tn'], order=modelo_auto.order)
        modelo_entrenado = modelo.fit()

        # Predecir las ventas para los próximos dos períodos
        predicciones = modelo_entrenado.forecast(steps=1) #2

        # Agregar las predicciones a la lista de resultados
        resultados_por_producto.append({'product_id': producto,
                                        'prediccion_1': predicciones[0]})
                                        #'prediccion_2': predicciones[1]})
    except Exception as e:
        print(f"Error al procesar el producto {producto}: {str(e)}")
        resultados_por_producto.append({'product_id': producto,
                                        'prediccion_1': 0})
                                        #'prediccion_2': 0})

# Convertir la lista de resultados en un DataFrame
predicciones_por_producto = pd.DataFrame(resultados_por_producto)

# Mostrar el DataFrame con las predicciones por producto
print(predicciones_por_producto)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# ...

# %%
predicciones_por_producto.to_csv('/content/drive/MyDrive/pred_arima_36m.csv', index=False)

# %% [markdown]
# ##LSTM

# %%
import pandas as pd
import numpy as np

# %%
# monta G-drive en entorno COLAB
from google.colab import drive
drive.mount('/content/drive/')

file_path3= '/content/drive/MyDrive/productos_a_predecir.txt'
productos_predecir = pd.read_csv(file_path3, sep='\t')

file_path = '/content/drive/MyDrive/sell-in.txt'
sell_in = pd.read_csv(file_path, sep='\t')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Definir los periodos de interés
#periodos = [201701,201702,201703,201704,201705,201706,201707,201708,201709,201710,201711,201712,201801,201802,201803,201804,201805,201806,201807,201808,201809,201810,201811,201812,201901,201902,201903,201904,201905,201906,201907,201908,201909,201910,201911,201912]
periodos = [201901,201902,201903,201904,201905,201906,201907,201908,201909,201910,201911,201912]
# Filtrar las filas correspondientes a los periodos de interés
sell_in_completo = sell_in[sell_in['periodo'].isin(periodos)]

# %%
sell_in_completo.head()
# Out:
#          periodo  customer_id  product_id  plan_precios_cuidados  \
# 2035338   201901        10461       20524                      0
# 2035339   201901        10035       20524                      0
# 2035340   201901        10027       20524                      0
# 2035341   201901        10159       20524                      0
# 2035342   201901        10282       20524                      0
#
#          cust_request_qty  cust_request_tn       tn
# 2035338                 1          0.01514  0.01514
# 2035339                 1          0.03786  0.03786
# 2035340                 6          0.14385  0.14385
# 2035341                 3          0.02271  0.02271
# 2035342                 1          0.01514  0.01514

# %%
dataset = pd.merge(productos_predecir, sell_in_completo, on='product_id', how='inner')

# %%
#dataset.to_csv('/content/drive/MyDrive/df.csv', index=False)

# %%
sell_in_completo = dataset.groupby(['periodo', 'product_id'])['tn'].sum().reset_index()

# %%
sell_in_completo['periodo'] = pd.to_datetime(sell_in_completo['periodo'].astype(str) + '01', format='%Y%m%d')

# %%
sell_in_completo.set_index("periodo", inplace=True)

# %%
# univariate bidirectional lstm example
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Bidirectional

# %%
#9.4 Multi-step LSTM Models

#VER SI ESTO SIRVE
# split a univariate sequence into samples
#def split_sequence(sequence, n_steps_in, n_steps_out):
#X, y = list(), list()
#for i in range(len(sequence)):
# find the end of this pattern
#end_ix = i + n_steps_in
#out_end_ix = end_ix + n_steps_out
# check if we are beyond the sequence
#if out_end_ix > len(sequence):
#break
# gather input and output parts of the pattern
#seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
#X.append(seq_x)
#y.append(seq_y)
#return array(X), array(y)

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional

# Supongamos que sell_in_completo ya está definido y cargado con los datos correctos
# sell_in_completo = pd.read_csv('ruta_al_archivo.csv') # Ejemplo de carga de datos

# %%
# Lista para acumular las filas de resultados
resultados_por_producto = []

# choose a number of time steps
n_steps = 2
n_features = 1  # Cambia esto si tienes más características

# Asegúrate de que productos_unicos está definido
productos_unicos = sell_in_completo["product_id"].unique()



#ESTO CREA MUCHOS DATASETS--- n_steps entiendo que deberia ser 2
def crear_secuencias(datos, n_steps):
    X, y = [], []
    for i in range(len(datos)):
        end_ix = i + n_steps
        if end_ix > len(datos)-1:
            break
        seq_x, seq_y = datos[i:end_ix], datos[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

for producto in productos_unicos:
    # Filtrar datos para el producto específico
    aux = sell_in_completo[sell_in_completo["product_id"] == producto].drop(columns=["product_id"]).values

    try:
        # Crear secuencias de tiempo  # transform input from [samples, features] to [samples, timesteps, features]
        X, y = crear_secuencias(aux, n_steps)
        X = X.reshape((X.shape[0], X.shape[1], n_features))

        # Definir el modelo
        model = Sequential()
        model.add(Bidirectional(LSTM(50, activation='relu'), input_shape=(n_steps, n_features)))  #50 refers to the number of units in the first hidden layer. The number of units in the first hidden
                                                                                                  #layer is completely unrelated to the number of samples, time steps or features in your input
                                                                                                  #data.

        model.add(Dense(1))
        model.compile(optimizer='adam', loss='mse')

        # Entrenar el modelo
        model.fit(X, y, epochs=300, verbose=0)

        # Preparar los datos para la predicción
        # Tomar la última secuencia de datos para predecir el próximo período
        ultima_secuencia = aux[-n_steps:].reshape((1, n_steps, n_features))

        # Predecir las ventas para el próximo período
        prediccion = model.predict(ultima_secuencia)

        # Agregar las predicciones a la lista de resultados
        resultados_por_producto.append({'product_id': producto,
                                        'prediccion_1': prediccion[0][0]})
    except Exception as e:
        print(f"Error al procesar el producto {producto}: {str(e)}")
        resultados_por_producto.append({'product_id': producto,
                                        'prediccion_1': 0})

# Convertir la lista de resultados en un DataFrame
predicciones_por_producto = pd.DataFrame(resultados_por_producto)

# Mostrar el DataFrame con las predicciones por producto
print(predicciones_por_producto)

predicciones_por_producto.to_csv('/content/drive/MyDrive/pred_lstm_36v3step.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-826ae990dc8a> in <cell line: 25>()
#      42
#      43         # Entrenar el modelo
# ---> 44         model.fit(X, y, epochs=300, verbose=0)
#      45
#      46         # Preparar los datos para la predicción
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
pip install keras-tuner

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense
import tensorflow as tf  # Asegúrate de importar TensorFlow
import keras_tuner as kt

# Lista para acumular las filas de resultados
resultados_por_producto = []

# Elegir un número de pasos de tiempo
n_steps = 2
n_features = 1  # Cambia esto si tienes más características

# Asegúrate de que productos_unicos está definido
productos_unicos = sell_in_completo["product_id"].unique()

# Función para crear secuencias de tiempo
def crear_secuencias(datos, n_steps, step_ahead=1):
    X, y = [], []
    for i in range(len(datos)):
        end_ix = i + n_steps
        out_end_ix = end_ix + step_ahead - 1
        if out_end_ix > len(datos) - 1:
            break
        seq_x, seq_y = datos[i:end_ix], datos[out_end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# Inicializar scaler
scaler = MinMaxScaler()

# Definir la función del modelo para Keras Tuner
def build_model(hp):
    model = Sequential()
    model.add(Bidirectional(LSTM(units=hp.Int('units', min_value=32, max_value=512, step=32),
                                 activation='relu'),
                            input_shape=(n_steps, n_features)))
    model.add(Dense(1))
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                  loss='mse')
    return model

# Inicializar el tuner
tuner = kt.RandomSearch(build_model,
                        objective='val_loss',
                        max_trials=5,
                        executions_per_trial=3,
                        directory='my_dir',
                        project_name='intro_to_kt')

# Variable para guardar los mejores hiperparámetros por producto
mejores_hiperparametros = []

for producto in productos_unicos:
    # Filtrar datos para el producto específico
    aux = sell_in_completo[sell_in_completo["product_id"] == producto].drop(columns=["product_id"]).values

    try:
        # Normalizar los datos
        aux_normalizado = scaler.fit_transform(aux)

        # Crear secuencias de tiempo
        X, y = crear_secuencias(aux_normalizado, n_steps, step_ahead=2)
        X = X.reshape((X.shape[0], X.shape[1], n_features))

        # Dividir datos en conjuntos de entrenamiento y validación
        split = int(0.8 * len(X))
        X_train, X_val = X[:split], X[split:]
        y_train, y_val = y[:split], y[split:]

        # Buscar los mejores hiperparámetros
        tuner.search(X_train, y_train, epochs=50, validation_data=(X_val, y_val), verbose=0)
        best_hp = tuner.get_best_hyperparameters()[0]
        mejores_hiperparametros.append({'product_id': producto, 'units': best_hp.get('units'), 'learning_rate': best_hp.get('learning_rate')})

        # Construir el mejor modelo
        model = tuner.hypermodel.build(best_hp)

        # Entrenar el modelo
        model.fit(X_train, y_train, epochs=300, validation_data=(X_val, y_val), verbose=0)

        # Preparar los datos para la predicción
        # Tomar la penúltima secuencia de datos para predecir dos períodos adelante
        ultima_secuencia = aux_normalizado[-(n_steps + 1):-1].reshape((1, n_steps, n_features))

        # Predecir las ventas para el próximo período
        prediccion_normalizada = model.predict(ultima_secuencia)

        # Desnormalizar la predicción
        prediccion = scaler.inverse_transform(prediccion_normalizada)

        # Agregar las predicciones a la lista de resultados
        resultados_por_producto.append({'product_id': producto, 'prediccion_1': prediccion[0][0]})
    except Exception as e:
        print(f"Error al procesar el producto {producto}: {str(e)}")
        resultados_por_producto.append({'product_id': producto, 'prediccion_1': 0})

# Convertir la lista de resultados en un DataFrame
predicciones_por_producto = pd.DataFrame(resultados_por_producto)
mejores_hiperparametros_df = pd.DataFrame(mejores_hiperparametros)

# Mostrar el DataFrame con las predicciones por producto
print(predicciones_por_producto)

# Guardar el DataFrame con las predicciones por producto en un archivo CSV
predicciones_por_producto.to_csv('/content/drive/MyDrive/pred_lstm_36v2step.csv', index=False)
mejores_hiperparametros_df.to_csv('/content/drive/MyDrive/mejores_hiperparametros.csv', index=False)
# Out:
# Reloading Tuner from my_dir/intro_to_kt/tuner0.json
# ...
# 1/1 [==============================] - 1s 1s/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7800040a9870> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 493ms/step
# ...

# %%
#VER
 #walk-forward validation for univariate data
#def walk_forward_validation(data, n_test, cfg):
#predictions = list()
# split dataset
#train, test = train_test_split(data, n_test)
# fit model
#model = model_fit(train, cfg)
# seed history with training dataset
#history = [x for x in train]
# step over each time step in the test set
##for i in range(len(test)):
# fit model and make forecast for history
#yhat = model_predict(model, history, cfg)
# store forecast in list of predictions
#predictions.append(yhat)
# add actual observation to history for the next loop
#history.append(test[i])
# estimate prediction error
#error = measure_rmse(test, predictions)
#print(' > %.3f' % error)
#return error
