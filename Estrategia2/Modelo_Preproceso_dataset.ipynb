# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/content/final_dataset.csv', sep='\t')
df
# Out:
#        periodo  product_id  plan_precios_cuidados  cust_request_qty  \
# 0       201701       20001                      0               479
# 1       201702       20001                      0               432
# 2       201703       20001                      0               509
# 3       201704       20001                      0               279
# 4       201705       20001                      0               701
# ...        ...         ...                    ...               ...
# 22344   201912       21087                      0               115
# 22345   201909       21214                      0                 3
# 22346   201910       21214                      0                46
# 22347   201911       21214                      0                88
# 22348   201912       21214                      0                55
#
#        cust_request_tn           y cat1         cat2     cat3  brand  \
# 0            937.72717   934.77222   HC  ROPA LAVADO  Liquido  ARIEL
# 1            833.72187   798.01620   HC  ROPA LAVADO  Liquido  ARIEL
# 2           1330.74697  1303.35771   HC  ROPA LAVADO  Liquido  ARIEL
# 3           1132.94430  1069.96130   HC  ROPA LAVADO  Liquido  ARIEL
# 4           1550.68936  1502.20132   HC  ROPA LAVADO  Liquido  ARIEL
# ...                ...         ...  ...          ...      ...    ...
# 22344          1.05790     1.02205   PC         DEOS     Aero  NIVEA
# 22345          0.34250     0.34250   PC         DEOS   RollOn  NIVEA
# 22346          0.21735     0.21735   PC         DEOS   RollOn  NIVEA
# 22347          0.84012     0.84012   PC         DEOS   RollOn  NIVEA
# 22348          0.24428     0.24428   PC         DEOS   RollOn  NIVEA
#
#        sku_size  stock_final  close_quarter  age
# 0          3000          NaN              0    0
# 1          3000          NaN              0    1
# 2          3000          NaN              1    2
# 3          3000          NaN              0    3
# 4          3000          NaN              0    4
# ...         ...          ...            ...  ...
# 22344        65      5.79239              1    3
# 22345        50      2.59152              1    0
# 22346        50      1.65982              0    1
# 22347        50      0.52214              0    2
# 22348        50      2.69032              1    3
#
# [22349 rows x 14 columns]

# %% [markdown]
# Convertir la columna Date Time del formato object (string + datos numéricos) al formato datetime.

# %%
# Verificar que el tipo de dato es "object"
df['periodo'].dtype
# Out:
# dtype('int64')

# %%
# Pasar la columna "Date Time" al formato datetime
df['periodo1'] = pd.to_datetime(df['periodo'], format='%Y%m')


# Fijemos esta nueva columna como índice del DataFrame
df = df.set_index('periodo1')

# Ordenemos el dataset de forma ascendente según "datetime"
df.sort_index(inplace=True)

# Y finalmente eliminemos la columna "Date Time" original
df = df.drop(columns=['periodo'])
df
# Out:
#             product_id  plan_precios_cuidados  cust_request_qty  \
# periodo1
# 2017-01-01       20001                      0               479
# 2017-01-01       20335                      0               273
# 2017-01-01       20715                      0               290
# 2017-01-01       20095                      0               222
# 2017-01-01       20470                      0               226
# ...                ...                    ...               ...
# 2019-12-01       20176                      0               293
# 2019-12-01       20970                      0                58
# 2019-12-01       21073                      0               103
# 2019-12-01       20179                      0               216
# 2019-12-01       21214                      0                55
#
#             cust_request_tn          y   cat1            cat2  \
# periodo1
# 2017-01-01        937.72717  934.77222     HC     ROPA LAVADO
# 2017-01-01         25.46758   25.41893     PC         CABELLO
# 2017-01-01          4.95717    4.95717  FOODS  SOPAS Y CALDOS
# 2017-01-01         51.85641   51.85641  FOODS        ADEREZOS
# 2017-01-01          8.31922    8.31922     PC         CABELLO
# ...                     ...        ...    ...             ...
# 2019-12-01         23.87612   23.87612     PC         CABELLO
# 2019-12-01          0.43677    0.43677  FOODS  SOPAS Y CALDOS
# 2019-12-01          0.75292    0.75292     HC           HOGAR
# 2019-12-01         39.86679   39.70194     PC         CABELLO
# 2019-12-01          0.24428    0.24428     PC            DEOS
#
#                          cat3      brand  sku_size  stock_final  \
# periodo1
# 2017-01-01            Liquido      ARIEL      3000          NaN
# 2017-01-01        Acond Mujer      NIVEA       750          NaN
# 2017-01-01        Baking Bags      MAGGI        15          NaN
# 2017-01-01            Ketchup     NATURA       500          NaN
# 2017-01-01            SHAMPOO  CAPILATIS       400          NaN
# ...                       ...        ...       ...          ...
# 2019-12-01            SHAMPOO   SHAMPOO3       200     13.31799
# 2019-12-01  Caldos Granulados      MAGGI         4      1.09855
# 2019-12-01           TOILETTE     AYUDIN        35      3.53917
# 2019-12-01            SHAMPOO   SHAMPOO3       300     -0.00336
# 2019-12-01             RollOn      NIVEA        50      2.69032
#
#             close_quarter  age
# periodo1
# 2017-01-01              0    0
# 2017-01-01              0    0
# 2017-01-01              0    0
# 2017-01-01              0    0
# 2017-01-01              0    0
# ...                   ...  ...
# 2019-12-01              1   35
# 2019-12-01              1   35
# 2019-12-01              1    9
# 2019-12-01              1   35
# 2019-12-01              1    3
#
# [22349 rows x 13 columns]

# %%
df = df.drop("stock_final", axis=1)
df = df.rename(columns={'tn': 'y'})
df
# Out:
#             product_id  plan_precios_cuidados  cust_request_qty  \
# periodo1
# 2017-01-01       20001                      0               479
# 2017-01-01       20335                      0               273
# 2017-01-01       20715                      0               290
# 2017-01-01       20095                      0               222
# 2017-01-01       20470                      0               226
# ...                ...                    ...               ...
# 2019-12-01       20176                      0               293
# 2019-12-01       20970                      0                58
# 2019-12-01       21073                      0               103
# 2019-12-01       20179                      0               216
# 2019-12-01       21214                      0                55
#
#             cust_request_tn          y   cat1            cat2  \
# periodo1
# 2017-01-01        937.72717  934.77222     HC     ROPA LAVADO
# 2017-01-01         25.46758   25.41893     PC         CABELLO
# 2017-01-01          4.95717    4.95717  FOODS  SOPAS Y CALDOS
# 2017-01-01         51.85641   51.85641  FOODS        ADEREZOS
# 2017-01-01          8.31922    8.31922     PC         CABELLO
# ...                     ...        ...    ...             ...
# 2019-12-01         23.87612   23.87612     PC         CABELLO
# 2019-12-01          0.43677    0.43677  FOODS  SOPAS Y CALDOS
# 2019-12-01          0.75292    0.75292     HC           HOGAR
# 2019-12-01         39.86679   39.70194     PC         CABELLO
# 2019-12-01          0.24428    0.24428     PC            DEOS
#
#                          cat3      brand  sku_size  close_quarter  age
# periodo1
# 2017-01-01            Liquido      ARIEL      3000              0    0
# 2017-01-01        Acond Mujer      NIVEA       750              0    0
# 2017-01-01        Baking Bags      MAGGI        15              0    0
# 2017-01-01            Ketchup     NATURA       500              0    0
# 2017-01-01            SHAMPOO  CAPILATIS       400              0    0
# ...                       ...        ...       ...            ...  ...
# 2019-12-01            SHAMPOO   SHAMPOO3       200              1   35
# 2019-12-01  Caldos Granulados      MAGGI         4              1   35
# 2019-12-01           TOILETTE     AYUDIN        35              1    9
# 2019-12-01            SHAMPOO   SHAMPOO3       300              1   35
# 2019-12-01             RollOn      NIVEA        50              1    3
#
# [22349 rows x 12 columns]

# %%
# Verificar si hay datos faltantes
print('Cantidad de NaNs:')
for column in df:
    nans = df[column].isna().sum()
    print(f'\tColumna {column}: {nans}')
# Out:
# Cantidad de NaNs:
# 	Columna product_id: 0
# 	Columna plan_precios_cuidados: 0
# 	Columna cust_request_qty: 0
# 	Columna cust_request_tn: 0
# 	Columna y: 0
# 	Columna cat1: 0
# 	Columna cat2: 0
# 	Columna cat3: 0
# 	Columna brand: 0
# 	Columna sku_size: 0
# 	Columna close_quarter: 0
# 	Columna age: 0

# %%
# Calculate differences (in days) between each pair of consecutive data points
df_time_diffs = df.index.to_series().diff().dt.days
print(df_time_diffs.value_counts())
# Out:
# periodo1
# 0.0     22313
# 31.0       20
# 30.0       12
# 28.0        3
# Name: count, dtype: int64

# %%
# Eliminar duplicados para corregir el problema de diferencias
# de 0.0 s
df.drop_duplicates(keep='first', inplace=True, ignore_index=False)

# Y verificar que han sido eliminados
df_time_diffs = df.index.to_series().diff().dt.total_seconds()
print(df_time_diffs.value_counts())
# Out:
# periodo1
# 0.0          22313
# 2678400.0       20
# 2592000.0       12
# 2419200.0        3
# Name: count, dtype: int64

# %%
# Verificar que el dataset resultante no contiene NaNs:
print('Cantidad de NaNs:')
for column in df:
    nans = df[column].isna().sum()
    print(f'\tColumna {column}: {nans}')
# Out:
# Cantidad de NaNs:
# 	Columna product_id: 0
# 	Columna plan_precios_cuidados: 0
# 	Columna cust_request_qty: 0
# 	Columna cust_request_tn: 0
# 	Columna y: 0
# 	Columna cat1: 0
# 	Columna cat2: 0
# 	Columna cat3: 0
# 	Columna brand: 0
# 	Columna sku_size: 0
# 	Columna close_quarter: 0
# 	Columna age: 0

# %%
df.to_csv("/content/final_dataset.csv")
